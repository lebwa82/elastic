# %%
from torch import tensor
my_words = ['SOCCER', '-', 'JAPAN', 'GET', 'LUCKY', 'WIN', ',', 'CHINA', 'IN', 'SURPRISE', 'DEFEAT', '.']
my_ngrams = [['SOCCER'], ['SOCCER', '-'], ['SOCCER', '-', 'JAPAN'], ['SOCCER', '-', 'JAPAN', 'GET'], ['-'], ['-', 'JAPAN'], ['-', 'JAPAN', 'GET'], ['-', 'JAPAN', 'GET', 'LUCKY'], ['JAPAN'], ['JAPAN', 'GET'], ['JAPAN', 'GET', 'LUCKY'], ['JAPAN', 'GET', 'LUCKY', 'WIN'], ['GET'], ['GET', 'LUCKY'], ['GET', 'LUCKY', 'WIN'], ['GET', 'LUCKY', 'WIN', ','], ['LUCKY'], ['LUCKY', 'WIN'], ['LUCKY', 'WIN', ','], ['LUCKY', 'WIN', ',', 'CHINA'], ['WIN'], ['WIN', ','], ['WIN', ',', 'CHINA'], ['WIN', ',', 'CHINA', 'IN'], [','], [',', 'CHINA'], [',', 'CHINA', 'IN'], [',', 'CHINA', 'IN', 'SURPRISE'], ['CHINA'], ['CHINA', 'IN'], ['CHINA', 'IN', 'SURPRISE'], ['CHINA', 'IN', 'SURPRISE', 'DEFEAT'], ['IN'], ['IN', 'SURPRISE'], ['IN', 'SURPRISE', 'DEFEAT'], ['IN', 'SURPRISE', 'DEFEAT', '.'], ['SURPRISE'], ['SURPRISE', 'DEFEAT'], ['SURPRISE', 'DEFEAT', '.'], ['DEFEAT'], ['DEFEAT', '.'], ['.']]
my_predicts = tensor([[[1.0000e+00, 1.3316e-12, 2.7060e-13, 5.3566e-12, 1.6384e-12],
         [1.0000e+00, 2.9726e-15, 3.5172e-15, 2.0091e-14, 1.8484e-14],
         [1.0000e+00, 5.6755e-10, 8.3001e-11, 5.1150e-07, 6.0741e-09],
         [1.0000e+00, 5.4358e-17, 4.8028e-17, 9.2453e-17, 3.0256e-16],
         [1.0000e+00, 2.1803e-14, 3.0364e-14, 2.3122e-13, 2.5222e-13],
         [9.9999e-01, 1.2185e-08, 2.5106e-09, 1.1250e-05, 2.2190e-07],
         [1.0000e+00, 4.1900e-16, 6.7058e-16, 7.3446e-16, 4.9728e-15],
         [1.0000e+00, 8.0193e-15, 1.6314e-14, 3.3243e-14, 4.6139e-13],
         [1.0214e-06, 1.8278e-07, 4.2197e-09, 1.0000e+00, 7.6611e-08],
         [1.0000e+00, 9.6830e-12, 4.7401e-12, 2.5985e-10, 5.5970e-12],
         [1.0000e+00, 1.3752e-10, 1.7192e-10, 1.9742e-08, 7.7750e-10],
         [1.0000e+00, 5.5812e-15, 1.7617e-15, 3.5363e-13, 1.9018e-14],
         [1.0000e+00, 2.7226e-12, 6.8496e-12, 6.1695e-12, 1.4793e-11],
         [1.0000e+00, 4.9905e-11, 2.8286e-10, 2.2544e-10, 2.0134e-09],
# %%
len(my_all_span_idxs) == len(my_ngrams)
# Out:
# True

# %%
len(my_ngrams)
# Out:
# 42

# %%
import time
new_predicts = []

my_predicts_list = my_predicts.tolist()[0]
new_predicts_count_ngram_for_word = []
for i in range(len(my_words)):
    new_predicts.append([0, 0, 0, 0, 0])
    new_predicts_count_ngram_for_word.append(0)

#print(my_predicts_list)

for i in range(len(my_predicts_list)):
    start = my_all_span_idxs[i][0]
    end = my_all_span_idxs[i][1]
    for index in range(start, end+1):
        #print(index)

        new_predicts[index]  = [x+y for x,y in zip(new_predicts[index] , my_predicts_list[i])]
        new_predicts_count_ngram_for_word[index] += 1
        #print(new_predicts)
        #time.sleep(2)

normalized_predict = []
for i in range(len(new_predicts)):
    result = [x/new_predicts_count_ngram_for_word[i] for x in new_predicts[i]]
    normalized_predict.append(result)

# %%
import pprint
pprint.pprint(normalized_predict)
# Out:
# [[1.0,
#   1.4222115848180072e-10,
#   2.0818791783915207e-11,
#   1.2787634189773758e-07,
#   1.518939269079556e-09],
#  [0.9999985694885254,
#   1.8217975644533658e-09,
#   3.7052169512418006e-10,
#   1.6802143495338149e-06,
#   3.2567833218076845e-08],
#  [0.8888878897577368,
#   2.1742196209810994e-08,
#   7.766644441158462e-10,
#   0.11111242016693322,
#   3.392985331510606e-08],
#  [1.0,
#   1.9984703765193238e-11,
#   4.663927974573909e-11,
#   2.023385792311111e-09,
#   2.811853897089929e-10],
#  [0.999974000453949,
#   4.0329649553569186e-07,
#   3.7330557819498436e-06,
#   9.94047400239271e-07,
#   2.0578707177849284e-05],
#  [1.0,
#   4.778583792256821e-11,
#   1.104646996834842e-10,
#   6.915842688751463e-10,
#   1.4281832187712555e-09],
#  [1.0,
#   2.108150168662143e-12,
#   1.1708966700931487e-12,
#   7.073577206594316e-10,
#   1.4542369049764364e-10],
#  [0.9000012061000234,
#   3.6596205595398357e-10,
#   2.3801102695511832e-11,
#   0.09999909116798932,
# ...

# %%
i = 0
for word in normalized_predict:
    res = sum(word)
    print(res)

# %%
threshold = 0.5

# %%
len(normalized_predict)
# Out:
# 12

# %%
i = 0
final_predict = []
while i < len(normalized_predict):
    res_predict = [0, 0, 0, 0, 0]
    end = i
    while end < i + 4 and end < len(normalized_predict):
        end += 1
        print(end)
        j = i
        while j < end and j < len(normalized_predict):
            res_predict = [x+y for x,y in zip(res_predict, normalized_predict[j])]#предсказание для спана
            j += 1
        for el in range(len(res_predict)):
            res_predict[el] = res_predict[el]/(end-i)#нормализация
        for el in range(len(res_predict)):
            if res_predict[el] > threshold:
                res_predict[el] = 1
            else:
                res_predict[el] = 0

        final_predict.append(res_predict)
            
    i+=1

# %%
pprint.pprint(final_predict)

# %%
len(final_predict)
# Out:
# 42
